# %%
import pandas as pd
import plotly.graph_objects as go
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("./Dataset/ABC_data.csv")
df.head()
# Out:
#          date   open    high    low  close   volume Name
# 0  2013-02-08  46.52  46.895  46.46  46.89  1232802  ABC
# 1  2013-02-11  46.85  47.000  46.50  46.76  1115888  ABC
# 2  2013-02-12  46.70  47.050  46.60  46.96  1318773  ABC
# 3  2013-02-13  46.74  46.900  46.60  46.64  2645247  ABC
# 4  2013-02-14  46.67  46.990  46.60  46.77  1941879  ABC

# %%
candlestick = go.Figure(data=[go.Candlestick(x=df['date'],
                open=df['open'],
                high=df['high'],
                low=df['low'],
                close=df['close'])])

# %%
candlestick.show()
# Out:
# <div>
#
#
#             <div id="7cdeb4b2-f655-4959-ad9b-719fb33deae0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7cdeb4b2-f655-4959-ad9b-719fb33deae0")) {
#                     Plotly.newPlot(
#                         '7cdeb4b2-f655-4959-ad9b-719fb33deae0',
# ...

# %%
df['SMA_25'] = df.iloc[:,4].rolling(window=25).mean()
df['SMA_50'] = df.iloc[:,4].rolling(window=50).mean()

# %%
plt.figure(figsize=[15,10])
plt.grid(True)
plt.plot(df['SMA_25'],label='SMA 25 Days')
plt.plot(df['SMA_50'],label='SMA 50 days')
plt.legend(loc=2)

# %%
df['EMA_25'] = df.close.ewm(span=25, adjust=False).mean()
df['EMA_50'] = df.close.ewm(span=50, adjust=False).mean()

# %%
plt.grid(True)
plt.plot(df[], label='AMD 20 Day EMA')
plt.plot(df[], exp2, label='AMD 50 Day EMA')
plt.legend(loc='upper left')
plt.show()
